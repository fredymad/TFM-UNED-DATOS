# %% [markdown]
# # Objetivo
#
# Este script es el tercero de una serie de scripts utilizados en el TFM para crear un corpus adicional de notas con el que enriquecer el conjunto de entrenamiento de MEDDOPROF.
#
# Como input lee las notas almacenadas en la carpeta `/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas`. Provenientes del script `2ExtraccionNotas`
#
# Una vez leídas estas notas vemos si existen duplicados entre ellas. Esto es totalmente plausible puesto que estamos cogiendo notas de varios corpus para construir el nuevo conjunto de datos. En esos corpus la misma nota puede tener diferentes nombres pero el contenido puede ser el mismo.
#
# Este script se divide en dos partes fundamentales:
#
# 1. Comprobación de notas duplicadas mediante la función `duplicated`
# 2. Comprobación de notas duplicadas muy parecidas pero que no sean exactas (se da el caso de que hay notas duplicados con distinto nivel de indexación o a las que se ha eliminado la cabecera en un corpus y en otro no)
#
# El output de este script es un mensaje en pantalla que nos indica:
#
# 1. Notas duplicadas
# 2. Semejanza entre pares de notas mediante TF-IDF. El valor obtenido lo vamos a usar para revisar finalmente las notas por si son duplicadas.

# %% [markdown]
# # Duplicidades sencillas

# %%
# Cargamos las librerías necesarias
import numpy as np
import pandas as pd
import re
import os, glob
from sklearn.datasets import load_files
import shutil

# Habilitamos display interactivo y enlace con nuestra cuenta de google
from google.colab import data_table
from google.colab import drive

# Enlazamos nuestro notebook en Colab con nuestro almacenamiento en Google Drive 
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# Define relative path to folder containing the text files
files_folder = "/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas"
notas = []

# Create a dataframe list by using a list comprehension
notas = [pd.read_csv(file, delimiter='\t') for file in glob.glob(os.path.join(files_folder ,"*.txt"))]
notas = pd.DataFrame(notas, columns = ['notas'])
# Out:
# /usr/local/lib/python3.8/dist-packages/pandas/core/internals/construction.py:540: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   values = np.array([convert(v) for v in values])

# %%
# Sacamos la ruta de cada archivo
glob.glob(os.path.join(files_folder ,"*.txt"))
# Out:
# ['/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas/es-S1137-66272013000200022-1.txt',
#  '/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas/es-S0376-78922009000100011-1.txt',
#  '/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas/es-S1137-66272011000100013-1.txt',
#  '/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas/caso_clinico_urologia434.txt',
#  '/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas/caso_clinico_atencion_primaria20.txt',
#  '/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas/casos_clinicos_cardiologia268.txt',
#  '/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas/casos_clinicos_cardiologia358.txt',
#  '/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas/casos_clinicos_cardiologia447.txt',
#  '/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas/casos_clinicos_cardiologia351.txt',
#  '/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas/32617223_ES.txt',
#  '/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas/cc_onco912.txt',
#  '/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas/32119083_ES.txt',
#  '/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas/cc_onco377.txt',
#  '/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas/casos_clinicos_cardiologia404.txt',
#  '/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas/cc_reumatologia88.txt',
#  '/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas/caso_clinico_urgencias70.txt',
#  '/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas/cc_onco1167.txt',
#  '/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas/casos_clinicos_cardiologia475.txt',
#  '/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas/caso_clinico_medicina_interna890.txt',
#  '/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas/caso_clinico_dermatologia38.txt',
#  '/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas/casos_clinicos_cardiologia108.txt',
#  '/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas/casos_clinicos_infecciosas157.txt',
#  '/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas/cc_covid94.txt',
#  '/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas/caso_clinico_endocrinologia145.txt',
#  '/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas/caso_clinico_urgencias78.txt',
#  '/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas/cc_reumatologia62.txt',
#  '/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas/cc_onco886.txt',
#  '/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas/casos_clinicos_cardiologia202.txt',
#  '/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas/casos_clinicos_cardiologia164.txt',
#  '/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas/caso_clinico_atencion_primaria166.txt',
#  '/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas/cc_reumatologia51.txt',
#  '/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas/caso_clinico_medtropical132.txt',
#  '/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas/cc_onco316.txt',
#  '/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas/casos_clinicos_cardiologia366.txt',
#  '/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas/caso_clinico_atencion_primaria116.txt',
#  '/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas/cc_otorrinolaringologia248.txt',
#  '/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas/casos_clinicos_pediatria8.txt',
#  '/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas/caso_clinico_urgencias86.txt',
#  '/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas/caso_clinico_atencion_primaria123.txt',
#  '/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas/cc_onco470.txt',
#  '/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas/casos_clinicos_cardiologia483.txt',
#  '/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas/cc_onco874.txt',
#  '/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas/cc_onco125.txt',
#  '/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas/cc_geneticas26.txt',
#  '/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas/caso_clinico_medicina_interna881.txt',
#  '/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas/casos_clinicos_cardiologia187.txt',
#  '/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas/cc_covid81.txt',
#  '/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas/casos_clinicos_infecciosas168.txt',
#  '/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas/es-S1137-66272014000100021-1.txt',
#  '/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas/cc_geneticas1.txt',
#  '/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas/cc_onco5.txt',
#  '/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas/cc_onco841.txt',
#  '/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas/cc_onco621.txt',
#  '/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas/cc_geneticas28.txt',
#  '/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas/caso_clinico_dermatologia594.txt',
#  '/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas/caso_clinico_endocrinologia74.txt',
#  '/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas/caso_clinico_urgencias199.txt',
#  '/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas/caso_clinico_medtropical109.txt',
#  '/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas/cc_onco170.txt',
#  '/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas/casos_clinicos_cardiologia130.txt',
#  '/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas/caso_clinico_neurologia234.txt',
#  '/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas/caso_clinico_dermatologia483.txt',
#  '/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas/es-S1137-66272011000100013-2.txt',
#  '/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas/casos_clinicos_cardiologia138.txt',
#  '/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas/caso_clinico_dermatologia414.txt',
#  '/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas/casos_clinicos_cardiologia293.txt',
#  '/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas/caso_clinico_medicina_interna142.txt',
#  '/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas/casos_clinicos_infecciosas201.txt',
#  '/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas/cc_reumatologia353.txt',
#  '/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas/cc_reumatologia76.txt',
#  '/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas/casos_clinicos_pediatria97.txt',
#  '/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas/es-S0465-546X2014000400012-1.txt',
#  '/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas/caso_clinico_oftalmologia285.txt',
#  '/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas/casos_clinicos_cardiologia395.txt',
#  '/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas/cc_reumatologia347.txt',
#  '/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas/cc_onco67.txt',
#  '/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas/casos_clinicos_cardiologia445.txt',
#  '/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas/casos_clinicos_cardiologia62.txt',
#  '/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas/cc_onco514.txt',
#  '/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas/caso_clinico_atencion_primaria76.txt',
#  '/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas/caso_clinico_atencion_primaria75.txt',
#  '/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas/cc_onco381.txt',
#  '/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas/caso_clinico_medicina_interna1003.txt',
#  '/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas/caso_clinico_medtropical111.txt',
#  '/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas/caso_clinico_atencion_primaria126.txt',
#  '/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas/caso_clinico_medicina_interna180.txt',
#  '/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas/32329981_ES.txt',
#  '/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas/casos_clinicos_cardiologia363.txt',
#  '/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas/casos_clinicos_cardiologia473.txt',
#  '/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas/cc_geneticas163.txt',
#  '/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas/caso_clinico_urgencias98.txt',
#  '/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas/cc_reumatologia359.txt',
#  '/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas/cc_covid114.txt',
#  '/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas/casos_clinicos_cardiologia169.txt',
#  '/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas/casos_clinicos_cardiologia283.txt',
#  '/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas/cc_onco1699.txt',
#  '/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas/cc_odontologia41.txt',
#  '/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas/caso_clinico_atencion_primaria155.txt',
#  '/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas/casos_clinicos_cardiologia77.txt',
#  '/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas/cc_reumatologia240.txt',
#  '/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas/caso_clinico_atencion_primaria140.txt',
#  '/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas/caso_clinico_neurologia245.txt',
#  '/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas/cc_covid101.txt',
#  '/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas/caso_clinico_atencion_primaria71.txt',
#  '/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas/casos_clinicos_infecciosas69.txt',
#  '/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas/cc_covid15.txt',
#  '/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas/cc_reumatologia60.txt',
#  '/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas/caso_clinico_urgencias89.txt',
#  '/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas/es-S1137-66272011000100013-3.txt',
#  '/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas/es-S1132-62552015000100006-1.txt',
#  '/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas/casos_clinicos_pediatria41.txt',
#  '/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas/caso_clinico_medicina_interna781.txt',
#  '/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas/cc_geneticas232.txt',
#  '/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas/caso_clinico_atencion_primaria77.txt',
#  '/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas/caso_clinico_medtropical2.txt',
#  '/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas/casos_clinicos_pediatria9.txt',
#  '/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas/cc_covid71.txt',
#  '/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas/casos_clinicos_infecciosas205.txt',
#  '/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas/caso_clinico_medicina_interna42.txt',
#  '/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas/cc_geneticas200.txt',
#  '/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas/cc_otorrinolaringologia243.txt',
#  '/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas/caso_clinico_urologia117.txt',
#  '/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas/casos_clinicos_cardiologia474.txt',
#  '/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas/caso_clinico_urologia178.txt',
#  '/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas/cc_onco1859.txt',
#  '/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas/caso_clinico_neurologia54.txt',
#  '/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas/cc_reumatologia86.txt',
#  '/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas/casos_clinicos_infecciosas59.txt',
#  '/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas/cc_reumatologia295.txt',
#  '/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas/cc_otorrinolaringologia433.txt',
#  '/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas/32318729_ES.txt',
#  '/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas/caso_clinico_dermatologia624.txt',
#  '/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas/caso_clinico_urologia321.txt',
#  '/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas/caso_clinico_oftalmologia279.txt',
#  '/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas/caso_clinico_medicina_interna577.txt',
#  '/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas/caso_clinico_radiologia1125.txt',
#  '/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas/cc_covid105.txt',
#  '/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas/casos_clinicos_cardiologia477.txt',
#  '/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas/cc_onco1545.txt',
#  '/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas/caso_clinico_atencion_primaria85.txt',
#  '/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas/caso_clinico_urgencias129.txt',
#  '/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas/es-S0465-546X2014000300010-1.txt',
#  '/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas/casos_clinicos_cardiologia348.txt',
#  '/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas/cc_onco1690.txt',
#  '/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas/casos_clinicos_cardiologia61.txt',
#  '/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas/cc_covid112.txt',
#  '/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas/cc_reumatologia265.txt',
#  '/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas/32602610_ES.txt',
#  '/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas/caso_clinico_dermatologia20.txt',
#  '/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas/caso_clinico_neurologia227.txt',
#  '/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas/casos_clinicos_cardiologia201.txt',
#  '/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas/casos_clinicos_cardiologia298.txt',
#  '/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas/casos_clinicos_cardiologia377.txt',
#  '/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas/caso_clinico_atencion_primaria130.txt',
#  '/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas/casos_clinicos_cardiologia183.txt',
#  '/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas/caso_clinico_oftalmologia218.txt',
#  '/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas/cc_covid98.txt',
#  '/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas/cc_odontologia43.txt',
#  '/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas/casos_clinicos_cardiologia175.txt',
#  '/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas/caso_clinico_neurologia351.txt',
#  '/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas/casos_clinicos_cardiologia434.txt',
#  '/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas/cc_onco1697.txt',
#  '/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas/cc_onco1728.txt',
#  '/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas/caso_clinico_medicina_interna431.txt',
#  '/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas/caso_clinico_urologia132.txt',
#  '/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas/cc_onco1782.txt',
#  '/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas/cc_otorrinolaringologia105.txt',
#  '/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas/caso_clinico_dermatologia419.txt',
#  '/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas/caso_clinico_medicina_interna16.txt',
#  '/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas/cc_geneticas105.txt',
#  '/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas/casos_clinicos_cardiologia435.txt',
#  '/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas/casos_clinicos_cardiologia470.txt',
#  '/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas/casos_clinicos_cardiologia290.txt',
#  '/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas/caso_clinico_medicina_interna114.txt',
#  '/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas/caso_clinico_atencion_primaria105.txt',
#  '/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas/cc_onco1586.txt',
#  '/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas/es-S0211-57352013000300011-1.txt',
#  '/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas/cc_geneticas222.txt',
#  '/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas/cc_geneticas150.txt',
#  '/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas/cc_onco1678.txt',
#  '/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas/caso_clinico_dermatologia660.txt',
#  '/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas/caso_clinico_atencion_primaria12.txt',
#  '/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas/caso_clinico_alergologia5.txt',
#  '/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas/caso_clinico_oftalmologia229.txt',
#  '/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas/cc_geneticas158.txt',
#  '/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas/caso_clinico_neurologia41.txt',
#  '/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas/casos_clinicos_cardiologia311.txt',
#  '/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas/casos_clinicos_infecciosas206.txt',
#  '/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas/cc_onco1826.txt',
#  '/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas/caso_clinico_urologia373.txt',
#  '/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas/cc_reumatologia92.txt',
#  '/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas/caso_clinico_dermatologia492.txt',
#  '/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas/casos_clinicos_infecciosas21.txt',
#  '/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas/casos_clinicos_cardiologia308.txt',
#  '/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas/cc_otorrinolaringologia277.txt',
#  '/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas/casos_clinicos_cardiologia210.txt',
#  '/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas/casos_clinicos_cardiologia319.txt',
#  '/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas/caso_clinico_medicina_interna43.txt',
#  '/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas/caso_clinico_dermatologia309.txt',
#  '/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas/cc_geneticas55.txt',
#  '/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas/casos_clinicos_cardiologia335.txt',
#  '/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas/caso_clinico_medicina_interna567.txt',
#  '/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas/casos_clinicos_cardiologia165.txt',
#  '/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas/cc_geneticas144.txt',
#  '/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas/caso_clinico_dermatologia451.txt',
#  '/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas/caso_clinico_medicina_interna563.txt',
#  '/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas/cc_reumatologia238.txt',
#  '/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas/cc_reumatologia5.txt',
#  '/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas/casos_clinicos_cardiologia405.txt',
#  '/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas/es-S0465-546X2011000300007-1.txt',
#  '/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas/caso_clinico_medtropical106.txt',
#  '/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas/cc_covid93.txt',
#  '/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas/cc_reumatologia52.txt',
#  '/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas/caso_clinico_radiologia1086.txt',
#  '/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas/caso_clinico_dermatologia573.txt',
#  '/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas/cc_reumatologia77.txt',
#  '/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas/casos_clinicos_pediatria74.txt',
#  '/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas/caso_clinico_medtropical114.txt',
#  '/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas/casos_clinicos_cardiologia239.txt',
#  '/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas/caso_clinico_medicina_interna597.txt',
#  '/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas/es-S0465-546X2009000300008-1.txt',
#  '/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas/cc_onco246.txt',
#  '/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas/cc_onco1205.txt',
#  '/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas/es-S0210-56912009000900008-1.txt',
#  '/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas/es-S0210-56912007000200007-3.txt',
#  '/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas/es-S0376-78922009000300005-1.txt',
#  '/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas/cc_onco797.txt',
#  '/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas/cc_onco1407.txt',
#  '/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas/cc_onco605.txt',
#  '/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas/cc_onco701.txt',
#  '/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas/cc_onco1131.txt',
#  '/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas/cc_onco759.txt',
#  '/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas/cc_onco1329.txt',
#  '/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas/casos_clinicos_infecciosas91.txt',
#  '/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas/cc_onco811.txt',
#  '/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas/cc_onco922.txt',
#  '/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas/cc_onco466.txt',
#  '/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas/cc_onco495.txt',
#  '/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas/cc_onco1265.txt',
#  '/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas/cc_onco917.txt',
#  '/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas/32168162_ES.txt',
#  '/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas/cc_onco977.txt',
#  '/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas/cc_onco68.txt',
#  '/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas/cc_onco532.txt',
#  '/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas/cc_onco456.txt',
#  '/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas/cc_onco1495.txt',
#  '/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas/cc_onco387.txt',
#  '/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas/cc_onco844.txt',
#  '/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas/cc_onco1213.txt',
#  '/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas/cc_onco96.txt',
#  '/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas/casos_clinicos_cardiologia70.txt',
#  '/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas/cc_onco338.txt',
#  '/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas/caso_clinico_medicina_interna86.txt',
#  '/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas/cc_onco397.txt',
#  '/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas/cc_onco304.txt',
#  '/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas/cc_onco1011.txt',
#  '/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas/caso_clinico_urgencias75.txt',
#  '/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas/cc_onco665.txt',
#  '/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas/cc_onco505.txt',
#  '/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas/cc_onco1335.txt',
#  '/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas/cc_onco509.txt',
#  '/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas/caso_clinico_atencion_primaria58.txt',
#  '/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas/casos_clinicos_cardiologia47.txt',
#  '/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas/cc_onco230.txt',
#  '/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas/cc_onco601.txt',
#  '/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas/cc_onco1038.txt',
#  '/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas/caso_clinico_medicina_interna112.txt',
#  '/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas/cc_onco1227.txt',
#  '/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas/cc_onco890.txt',
#  '/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas/cc_onco916.txt',
#  '/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas/cc_onco103.txt',
#  '/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas/cc_onco201.txt',
#  '/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas/cc_onco181.txt',
#  '/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas/cc_onco424.txt',
#  '/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas/cc_onco544.txt',
#  '/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas/cc_onco159.txt',
#  '/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas/cc_onco234.txt',
#  '/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas/cc_onco926.txt',
#  '/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas/cc_onco602.txt',
#  '/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas/cc_onco290.txt',
#  '/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas/cc_onco945.txt',
#  '/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas/casos_clinicos_cardiologia195.txt',
#  '/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas/32085846_ES.txt',
#  '/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas/caso_clinico_medtropical134.txt',
#  '/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas/cc_onco95.txt',
#  '/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas/32222713_ES.txt',
#  '/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas/32554811_ES.txt',
#  '/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas/caso_clinico_medtropical140.txt',
#  '/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas/caso_clinico_medtropical17.txt',
#  '/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas/caso_clinico_urgencias198.txt',
#  '/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas/caso_clinico_medtropical50.txt',
#  '/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas/casos_clinicos_pediatria12.txt',
#  '/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas/caso_clinico_medicina_interna20.txt',
#  '/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas/caso_clinico_neurologia283.txt',
#  '/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas/casos_clinicos_cardiologia72.txt',
#  '/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas/casos_clinicos_cardiologia185.txt',
#  '/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas/cc_onco317.txt',
#  '/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas/caso_clinico_radiologia867.txt',
#  '/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas/casos_clinicos_cardiologia30.txt',
#  '/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas/caso_clinico_medicina_interna272.txt',
#  '/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas/casos_clinicos_cardiologia44.txt',
#  '/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas/casos_clinicos_infecciosas125.txt',
#  '/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas/caso_clinico_atencion_primaria56.txt',
#  '/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas/caso_clinico_urologia169.txt',
#  '/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas/caso_clinico_medtropical18.txt',
#  '/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas/casos_clinicos_cardiologia99.txt',
#  '/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas/casos_clinicos_cardiologia12.txt',
#  '/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas/casos_clinicos_infecciosas96.txt',
#  '/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas/32265235_ES.txt',
#  '/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas/caso_clinico_neurologia345.txt',
#  '/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas/casos_clinicos_cardiologia46.txt',
#  '/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas/caso_clinico_dermatologia66.txt',
#  '/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas/caso_clinico_dermatologia138.txt',
#  '/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas/caso_clinico_atencion_primaria50.txt',
#  '/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas/casos_clinicos_infecciosas102.txt',
#  '/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas/caso_clinico_medtropical27.txt',
#  '/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas/32425356_ES.txt',
#  '/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas/cc_onco271.txt',
#  '/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas/caso_clinico_atencion_primaria54.txt',
#  '/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas/cc_onco432.txt',
#  '/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas/S0004-06142008000200037-1.txt',
#  '/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas/S1132-62552015000200005-1.txt',
#  '/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas/S0034-98872016000400014-1.txt',
#  '/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas/S0716-10182012000600015-1.txt',
#  '/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas/S0211-57352011000400007-1.txt',
#  '/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas/S1135-76062014000100003-1.txt',
#  '/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas/S1578-25492016000400004-1.txt',
#  '/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas/S0211-57352014000300007-1.txt',
#  '/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas/S1135-76062011000300005-1.txt',
#  '/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas/S0034-98872015000100016-1.txt',
#  '/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas/S2254-28842014000300009-1.txt',
#  '/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas/S0376-78922009000400002-6.txt',
#  '/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas/S0210-48062007000500020-1.txt',
#  '/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas/S1130-52742010000200007-1.txt',
#  '/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas/S1135-76062014000100007-1.txt',
#  '/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas/S1137-66272013000300023-1.txt',
#  '/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas/S0211-57352013000400004-1.txt',
#  '/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas/S1130-05582013000400007-1.txt',
#  '/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas/S1132-12962015000300007-1.txt',
#  '/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas/S1132-62552016000200006-1.txt',
#  '/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas/S0034-98872007000900012-1.txt',
#  '/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas/S1135-76062012000100004-1.txt',
#  '/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas/S0716-10182015000400016-1.txt',
#  '/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas/S0034-98872011000500012-1.txt',
#  '/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas/S1699-695X2015000200009-1.txt',
#  '/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas/S0120-41572014000400005-1.txt',
#  '/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas/S0120-41572014000300003-1.txt',
#  '/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas/S1698-69462006000400014-1.txt',
#  '/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas/S0034-98872010000800010-1.txt',
#  '/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas/S0465-546X2016000300009-1.txt',
#  '/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas/S0034-98872011000900015-1.txt',
#  '/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas/S1135-76062007000100006-1.txt',
#  '/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas/S0212-71992007001000006-1.txt',
#  '/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas/S0716-10182015000500018-1.txt',
#  '/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas/S1135-76062012000300004-1.txt',
#  '/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas/S1139-13752009000400010-1.txt',
#  '/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas/S1130-01082010000600003-2.txt',
#  '/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas/S1139-76322014000500007-1.txt',
#  '/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas/S1135-76062004000200002-1.txt',
#  '/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas/S0120-41572012000100003-1.txt',
#  '/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas/S1134-928X2012000100008-1.txt',
#  '/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas/S0034-98872011000200014-1.txt',
#  '/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas/S1130-01082015000300010-1.txt',
#  '/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas/S0034-98872012001100011-1.txt',
#  '/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas/S1132-62552016000200005-1.txt',
#  '/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas/S0211-69952012000800029-1.txt',
#  '/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas/S1132-12962007000300008-1.txt',
#  '/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas/S1137-66272014000100019-2.txt',
#  '/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas/S1130-01082007000200013-1.txt',
#  '/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas/S1137-66272010000400007-2.txt',
#  '/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas/S1134-80462006000700006-1.txt',
#  '/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas/S1139-76322013000200008-1.txt',
#  '/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas/S0716-10182009000200009-1.txt',
#  '/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas/S0376-78922015000300012-1.txt',
#  '/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas/S1135-76062014000200008-1.txt',
#  '/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas/S0211-57352010000400006-1.txt',
#  '/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas/S1130-01082007000200015-1.txt',
#  '/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas/S1139-76322012000500009-1.txt',
#  '/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas/S0465-546X2014000400011-1.txt',
#  '/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas/S0211-57352014000400011-1.txt',
#  '/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas/S0211-57352014000400010-1.txt',
#  '/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas/S0716-10182005000100011-1.txt',
#  '/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas/S1135-76062004000200001-1.txt',
#  '/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas/S0212-71992004000700006-1.txt',
#  '/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas/S0365-66912011001000003-4.txt',
#  '/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas/S0378-48352006000600005-1.txt',
#  '/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas/S0465-546X2012000200009-1.txt',
#  '/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas/S1139-13752010000300012-1.txt',
#  '/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas/S1135-76062015000200010-1.txt',
#  '/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas/S1699-695X2009000200009-1.txt',
#  '/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas/S0034-98872012000500010-1.txt',
#  '/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas/S1135-76062014000200007-1.txt',
#  '/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas/S1130-01082017000900014-1.txt',
#  '/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas/S0034-98872013000800014-2.txt',
#  '/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas/S0120-41572009000400006-1.txt',
#  '/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas/S0376-78922013000200009-1.txt',
#  '/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas/S1137-66272006000100012-1.txt',
#  '/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas/S0716-10182014000400014-1.txt',
#  '/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas/S0210-56912007000100005-1.txt',
#  '/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas/S1132-62552015000300007-1.txt',
#  '/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas/S0716-10182010000100014-1.txt',
#  '/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas/S0325-00752008000100011-1.txt',
#  '/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas/S1138-123X2003000500006-1.txt',
#  '/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas/S0034-98872009000900011-1.txt',
#  '/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas/S0365-66912011001000003-3.txt',
#  '/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas/S2254-28842016000400014-1.txt',
#  '/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas/S0376-78922015000300011-1.txt',
#  '/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas/S0716-10182011000300012-2.txt',
#  '/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas/S0211-57352003000300009-1.txt',
#  '/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas/S0370-41062014000200012-1.txt',
#  '/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas/S0034-98872014000500016-1.txt',
#  '/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas/S1132-12962015000200005-1.txt',
#  '/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas/S1130-63432013000400011-1.txt',
#  '/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas/S0211-57352017000100007-1.txt',
#  '/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas/S1139-76322016000400015-1.txt',
#  '/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas/S1139-13752009000300010-2.txt',
#  '/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas/S1130-01082007001100017-2.txt',
#  '/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas/S1130-05582015000100006-1.txt',
#  '/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas/S1134-928X2017000100006-1.txt',
#  '/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas/S0034-98872009000900010-1.txt',
#  '/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas/S0370-41062014000300010-1.txt',
#  '/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas/S0120-41572014000400004-1.txt',
#  '/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas/S0370-41062014000100012-1.txt',
#  '/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas/S0034-98872010000800010-2.txt',
#  '/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas/S0465-546X2014000200015-1.txt',
#  '/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas/S0325-00752008000100011-2.txt',
#  '/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas/S1806-37132012000200017-1.txt',
#  '/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas/S0376-78922018000100018-1.txt',
#  '/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas/S0004-06142007000700009-1.txt',
#  '/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas/S1132-12962004000100005-1.txt',
#  '/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas/S1888-75462014000400007-1.txt',
#  '/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas/S1139-13752009000300010-1.txt',
#  '/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas/S1134-928X2013000400005-1.txt',
#  '/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas/S0376-78922017000200011-1.txt',
#  '/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas/S0211-57352002000100009-1.txt',
#  '/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas/S1135-76062009000300002-1.txt',
#  '/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas/S1130-01082011001200012-1.txt',
#  '/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas/S1132-62552015000300005-1.txt',
#  '/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas/S1130-01082015000300015-1.txt',
#  '/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas/S0004-06142009000800009-1.txt',
#  '/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas/S1887-85712017000100008-1.txt',
#  '/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas/S0210-48062004000200009-1.txt',
#  '/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas/S0034-98872011000900014-1.txt',
#  '/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas/S0034-98872013000800014-3.txt',
#  '/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas/S0716-10182013000600020-1.txt',
#  '/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas/S1130-01082010000400013-1.txt',
#  '/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas/S1887-85712013000100005-1.txt',
#  '/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas/S0376-78922014000300013-1.txt',
#  '/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas/S0465-546X2008000200010-1.txt',
#  '/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas/S0212-71992008000700009-1.txt',
#  '/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas/S1130-01082007000700011-2.txt',
#  '/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas/S0210-56912007000200007-3.txt',
#  '/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas/S0210-56912009000900008-1.txt',
#  '/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas/S0211-57352013000300012-1.txt',
#  '/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas/S1137-66272011000300022-1.txt',
#  '/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas/S0376-78922016000300010-1.txt',
#  '/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas/S0004-06142007000300011-1.txt',
#  '/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas/S0376-78922009000300010-1.txt',
#  '/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas/S0210-56912009000600008-1.txt',
#  '/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas/S0210-48062006000300015-1.txt',
#  '/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas/S1699-695X2015000300010-1.txt',
#  '/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas/S0213-12852005000400003-1.txt',
#  '/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas/S1699-695X2014000300010-1.txt',
#  '/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas/S0213-12852013000400006-1.txt',
#  '/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas/S0211-57352015000100011-2.txt',
#  '/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas/S1130-01082008000900011-1.txt',
#  '/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas/S0365-66912010000700004-1.txt',
#  '/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas/S1137-66272010000400007-1.txt',
#  '/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas/S1887-85712016000100005-1.txt',
#  '/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas/S0376-78922009000300005-1.txt',
#  '/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas/S0376-78922012000400009-1.txt',
#  '/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas/S1137-66272016000200015-1.txt',
#  '/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas/S0376-78922009000200008-1.txt',
#  '/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas/S1887-85712012000400006-1.txt',
#  '/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas/S1137-66272013000200022-1.txt',
#  '/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas/S1699-695X2015000200010-1.txt',
#  '/content/drive/MyDrive/Colab Notebooks/anotar/NotasDefinitivas/S0211-69952011000500011-3.txt']

# %%
# Eliminamos la ruta completa y dejamos solo el nombre del archivo
df = pd.DataFrame(notas, columns = ['notas'])
df['notas']=df['notas'].apply(str)
df["nombre"] = glob.glob(os.path.join(files_folder ,"*.txt"))
df['nombre'] = df.nombre.apply(lambda x: os.path.splitext(os.path.basename(x))[0])

# %%
#Vemos el df
df
# Out:
#                                                  notas  \
# 0      Paciente de 33 años de edad sin antecedentes...
# 1       Varón soltero de 37 años de edad, trabajado...
# 2    Empty DataFrame\nColumns: [Varón de 45 años, t...
# 3                             Anámnesis e historia ...
# 4                                       Motivo de c...
# ..                                                 ...
# 472    Paciente de 18 años de edad y sexo femenino ...
# 473    Mujer de 47 años que consulta en urgencias p...
# 474    Paciente de 33 años de edad sin antecedentes...
# 475    Mujer de 40 años que acude a la consulta de ...
# 476  Empty DataFrame\nColumns: [Hombre de 47 años, ...
#
#                                nombre
# 0        es-S1137-66272013000200022-1
# 1        es-S0376-78922009000100011-1
# 2        es-S1137-66272011000100013-1
# 3            caso_clinico_urologia434
# 4    caso_clinico_atencion_primaria20
# ..                                ...
# 472         S0376-78922009000200008-1
# 473         S1887-85712012000400006-1
# 474         S1137-66272013000200022-1
# 475         S1699-695X2015000200010-1
# 476         S0211-69952011000500011-3
#
# [477 rows x 2 columns]

# %% [markdown]
# Definimos una pipeline de pre-procesado para encontrar duplicidades sencillas

# %%
import nltk
from nltk.stem import *
from nltk.stem import WordNetLemmatizer
from nltk.corpus import stopwords
import re
# import contractions
nltk.download('stopwords')
nltk.download('wordnet')
nltk.download('omw-1.4') # Lo añadimos nuevo

# Cargamos el stemmer
from nltk.stem import SnowballStemmer
stemmer = SnowballStemmer('spanish')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!

# %% [markdown]
# Eliminamos stopwords y nos quedamos únicamente con caracteres alfanuméricos

# %%
def process_text(raw_text):
    cleantext = re.sub(re.compile('<.*?>'), '', raw_text)
    #Consideramos únicamente letras utilizando una expresión regular
    letters_only = re.sub("[^a-zA-Z]", " ", cleantext) 
    #Convertimos todo a minúsculas (normalizamos)
    words = letters_only.lower().split()
    
    #Eliminamos las stopwords
    stops = set(stopwords.words("spanish")) 
    not_stop_words = [w for w in words if not w in stops]
  
    #Stemming
    stemmer = SnowballStemmer('spanish')
    stemmed = [stemmer.stem(word) for word in not_stop_words]
    
    return(" ".join(stemmed))

# %%
# Creamos una columna con la nota limpia
df['notas_limpias'] = df['notas'].apply(lambda x: process_text(x))

# %%
df
# Out:
#                                                  notas  \
# 0      Paciente de 33 años de edad sin antecedentes...
# 1       Varón soltero de 37 años de edad, trabajado...
# 2    Empty DataFrame\nColumns: [Varón de 45 años, t...
# 3                             Anámnesis e historia ...
# 4                                       Motivo de c...
# ..                                                 ...
# 472    Paciente de 18 años de edad y sexo femenino ...
# 473    Mujer de 47 años que consulta en urgencias p...
# 474    Paciente de 33 años de edad sin antecedentes...
# 475    Mujer de 40 años que acude a la consulta de ...
# 476  Empty DataFrame\nColumns: [Hombre de 47 años, ...
#
#                                nombre  \
# 0        es-S1137-66272013000200022-1
# 1        es-S0376-78922009000100011-1
# 2        es-S1137-66272011000100013-1
# 3            caso_clinico_urologia434
# 4    caso_clinico_atencion_primaria20
# ..                                ...
# 472         S0376-78922009000200008-1
# 473         S1887-85712012000400006-1
# 474         S1137-66272013000200022-1
# 475         S1699-695X2015000200010-1
# 476         S0211-69952011000500011-3
#
#                                          notas_limpias
# 0    pacient edad antecedent inter s diagnostic enf...
# 1    var n solter edad trabaj camp envi servici hos...
# 2    empty datafram columns var n trabaj canter dia...
# 3    an mnesis histori cl nic acud deriv m dic aten...
# 4    motiv consult voluntad vital anticip vva enfoq...
# ..                                                 ...
# 472  pacient edad sex femenin oper extrofi cloac re...
# 473  muj consult urgenci cuadr hor evoluci n dolor ...
# 474  pacient edad antecedent inter s diagnostic enf...
# 475  muj acud consult atenci n primari dolor ambas ...
# 476  empty datafram columns hombr diabet tip larg e...
#
# [477 rows x 3 columns]

# %% [markdown]
# Duplicados conjunto a anotar, con el que vamos a enriquecer (MOD)

# %%
# Señalamos los duplicados
df["duplicados"] = df.notas_limpias.duplicated(keep = False)
df[df.duplicados == True].sort_values("notas")
# Out:
#                                                  notas  \
# 224    Niño de 9 años con faringitis desde hace 7 d...
# 451    Niño de 9 años con faringitis desde hace 7 d...
# 0      Paciente de 33 años de edad sin antecedentes...
# 474    Paciente de 33 años de edad sin antecedentes...
# 225    Paciente de 42 años, casada, unigesta (gemel...
# 469    Paciente de 42 años, casada, unigesta (gemel...
# 223    Se trata de un varón de 66 años con antecede...
# 452    Se trata de un varón de 66 años con antecede...
# 297    Varón de 27 años que presenta fiebre y hemop...
# 396    Varón de 27 años que presenta fiebre y hemop...
#
#                            nombre  \
# 224  es-S0210-56912007000200007-3
# 451     S0210-56912007000200007-3
# 0    es-S1137-66272013000200022-1
# 474     S1137-66272013000200022-1
# 225  es-S0376-78922009000300005-1
# 469     S0376-78922009000300005-1
# 223  es-S0210-56912009000900008-1
# 452     S0210-56912009000900008-1
# 297    caso_clinico_radiologia867
# 396     S1137-66272006000100012-1
#
#                                          notas_limpias  duplicados
# 224  faringitis hac d as fiebr elev artralgi hor pr...        True
# 451  faringitis hac d as fiebr elev artralgi hor pr...        True
# 0    pacient edad antecedent inter s diagnostic enf...        True
# 474  pacient edad antecedent inter s diagnostic enf...        True
# 225  pacient cas unigest gemel histori infeccion re...        True
# 469  pacient cas unigest gemel histori infeccion re...        True
# 223  trat var n antecedent neoplasi pulmon carcinom...        True
# 452  trat var n antecedent neoplasi pulmon carcinom...        True
# 297  var n present fiebr hemoptisis antecedent pers...        True
# 396  var n present fiebr hemoptisis antecedent pers...        True

# %% [markdown]
# Con el paso anterior localizamos notas con distinto nombre y mismo contenido entre las notas de los seis corpus que estamos utilizando para enriquecer el conjunto de MEDDOPROF (el que será el conjunto MOD)
#
# A continuación queremos identificar si hay casos en los que las notas seleccionadas para enriquecer MEDDOPROF también formen parte de este último bajo un nombre distinto (tanto el conjunto de entrenamiento como el conjunto de test). Esto es relevante dado que podríamos entrenar con una nota aparentemente nueva (localizada en alguno de los seis corpus) que estuviera en el conjunto de test de MEDDOPROF

# %% [markdown]
# Cargamos el conjunto de datos de train de MEDDOPROF

# %%
DATA_DIR_TRAIN = "/content/drive/MyDrive/Colab Notebooks/Corpus/MEDDOPROF/Original/Train/"
data = load_files(DATA_DIR_TRAIN, encoding="utf-8", decode_error="replace", shuffle=False)
data_train = pd.DataFrame(data.data, columns = ['texto'])
data_train['fichero'] = data.filenames

# Nos quedamos únicamente con los ficheros de estudio en base a como se organiza el corpus en carpetas
data_train = data_train[(data_train.fichero.str.contains('.txt', case=False, regex=False)) & (data_train.fichero.str.contains('task1', case=False, regex=False))]

#df["deteccion"] = df['texto'].str.contains('trabaj|ocupacion|profesion', case=False, regex=True)

#Eliminamos la ruta para comparar el nombre de las notas a revisar con las presentes en el conjunto de test de MEDDOPROF
data_train['fichero'] = data_train["fichero"].apply(lambda x: os.path.splitext(os.path.basename(x))[0])
data_train.head(5)
# Out:
#                                                texto      fichero
# 1  Un paciente de unos cincuenta años sin anteced...  32247016_ES
# 3  ﻿Una mujer de 27 años sin antecedentes, reside...  32294273_ES
# 5  ﻿Mujer de 66 años que acudió refiriendo dificu...  32399950_ES
# 7  ﻿El 28 de febrero de 2020 ingresó en urgencias...  32417987_ES
# 9  ﻿Una mujer de 31 años, por lo demás sana, acud...  32426200_ES

# %%
# Procesamos los textos del conjunto de train tal y como hicimos anteriormente
data_train['notas_limpias'] = data_train['texto'].apply(lambda x: process_text(x))

# %%
data_train
# Out:
#                                                   texto  \
# 1     Un paciente de unos cincuenta años sin anteced...
# 3     ﻿Una mujer de 27 años sin antecedentes, reside...
# 5     ﻿Mujer de 66 años que acudió refiriendo dificu...
# 7     ﻿El 28 de febrero de 2020 ingresó en urgencias...
# 9     ﻿Una mujer de 31 años, por lo demás sana, acud...
# ...                                                 ...
# 2991  Se presenta el caso de una paciente de 28 años...
# 2993  Paciente mujer de 81 años con hipoacusia bilat...
# 2995  Se presenta el caso de una mujer de 33 años qu...
# 2997  Se presenta el caso de un varón de 18 años de ...
# 2999  Varón de 24 años con adenopatía laterocervical...
#
#                         fichero  \
# 1                   32247016_ES
# 3                   32294273_ES
# 5                   32399950_ES
# 7                   32417987_ES
# 9                   32426200_ES
# ...                         ...
# 2991  cc_otorrinolaringologia54
# 2993  cc_otorrinolaringologia56
# 2995  cc_otorrinolaringologia60
# 2997  cc_otorrinolaringologia72
# 2999  cc_otorrinolaringologia96
#
#                                           notas_limpias
# 1     pacient cincuent antecedent personal acudi m d...
# 3     muj antecedent resident hospital present odino...
# 5     muj acudi refir dificult andar fatig agud hor ...
# 7     febrer ingres urgenci bomber tras crisis carac...
# 9     muj dem s san acudi servici urgenci s ntom fie...
# ...                                                 ...
# 2991  present cas pacient present hipoacusi hor evol...
# 2993  pacient muj hipoacusi bilateral progres larg e...
# 2995  present cas muj acud urgenci odinofagi fiebr e...
# 2997  present cas var n edad jornaler profesi n pres...
# 2999  var n adenopat laterocervical derech evoluci n...
#
# [1500 rows x 3 columns]

# %% [markdown]
# Vemos si existen duplicados en el conjunto de ENTRENAMIENTO de MEDDOPROF únicamente

# %%
# Señalamos los duplicados en el conjunto de entrenamiento
data_train["duplicados"] = data_train.notas_limpias.duplicated(keep = False)
data_train[data_train.duplicados == True].sort_values("texto")
# Out:
#                                                  texto  \
# 257  Motivo de Consulta\nAgresividad, impulsividad ...
# 259  Motivo de Consulta\nAgresividad, impulsividad ...
#
#                                fichero  \
# 257  caso_clinico_atencion_primaria161
# 259  caso_clinico_atencion_primaria162
#
#                                          notas_limpias  duplicados
# 257  motiv consult agres impuls insomni mal control...        True
# 259  motiv consult agres impuls insomni mal control...        True

# %% [markdown]
# Conjunto de test

# %%
DATA_DIR_TEST = "/content/drive/MyDrive/Colab Notebooks/Corpus/MEDDOPROF/Original/Test/"
data = load_files(DATA_DIR_TEST, encoding="utf-8", decode_error="replace", shuffle=False)

data_test = pd.DataFrame(data.data, columns = ['texto'])
data_test['fichero'] = data.filenames

# Nos quedamos únicamente con los ficheros de estudio en base a como se organiza el corpus en carpetas
data_test = data_test[(data_test.fichero.str.contains('.txt', case=False, regex=False)) & (data_test.fichero.str.contains('ner', case=False, regex=False))]

#df["deteccion"] = df['texto'].str.contains('trabaj|ocupacion|profesion', case=False, regex=True)

#Eliminamos la ruta para comparar el nombre de las notas a revisar con las presentes en el conjunto de test de MEDDOPROF
data_test['fichero'] = data_test["fichero"].apply(lambda x: os.path.splitext(os.path.basename(x))[0])
data_test.head(5)
# Out:
#                                                  texto  \
# 689  ﻿Un hombre de 36 años llegó al servicio de urg...
# 691  ﻿El señor G, un hombre de 43 años sin antecede...
# 693  ﻿Una mujer de 20 años embarazada secundigesta ...
# 695  Nombre:  Miriam .\nApellidos: Aguilar Mora.\nC...
# 697  Nombre: Paula.\nApellidos: De la Cruz Lorenzo....
#
#                        fichero
# 689                32423911_ES
# 691                32605766_ES
# 693                32614251_ES
# 695  S0004-06142009000100010-2
# 697  S0034-98872006000200011-1

# %%
# Procesamos los textos del conjunto de train tal y como hicimos anteriormente
data_test['notas_limpias'] = data_test['texto'].apply(lambda x: process_text(x))

# %% [markdown]
# Vemos si existen duplicados en el conjunto de TEST de MEDDOPROF únicamente

# %%
# Señalamos los duplicados en el conjunto de test
data_test["duplicados"] = data_test.notas_limpias.duplicated(keep = False)
data_test[data_test.duplicados == True].sort_values("texto")
# Out:
#                                                   texto  \
# 1051  Hombre de 47 años, empleado de la industria me...
# 1199  Hombre de 47 años, empleado de la industria me...
#
#                             fichero  \
# 1051  casos_clinicos_profesiones120
# 1199  casos_clinicos_profesiones193
#
#                                           notas_limpias  duplicados
# 1051  hombr emple industri metal rgic oper maquinari...        True
# 1199  hombr emple industri metal rgic oper maquinari...        True

# %% [markdown]
# Combinamos los distintos archivos para encontrar duplicados entre el conjunto de datos con el que vamos a enriquecer el entrenamiento con los datos de MEDDOPROF

# %%
# Creamos tres objetos que tengan el mismo aspecto para concatenar en un solo dataframe las notas provenientes de MEDDOPROF TRAIN/TEST con el conjunto de datos usado para enriquecer
# Conjunto de train procesado
df_train_procesado = data_train[["fichero", "notas_limpias", "duplicados"]]
df_train_procesado["conjunto"] = "train"
#df_train_procesado

# Conjunto de test procesado
df_test_procesado = data_test[["fichero", "notas_limpias", "duplicados"]]
df_test_procesado["conjunto"] = "test"
#df_test_procesado

# Conjunto de anotación con el que vamos a enriquecer
df_anotacion = df[["nombre", "notas_limpias", "duplicados"]].rename(columns = {'nombre':'fichero'})
df_anotacion["conjunto"] = "anotar"

# %%
df_final = pd.concat([df_train_procesado, df_test_procesado, df_anotacion]).reset_index()
df_final
# Out:
#       index                    fichero  \
# 0         1                32247016_ES
# 1         3                32294273_ES
# 2         5                32399950_ES
# 3         7                32417987_ES
# 4         9                32426200_ES
# ...     ...                        ...
# 2316    472  S0376-78922009000200008-1
# 2317    473  S1887-85712012000400006-1
# 2318    474  S1137-66272013000200022-1
# 2319    475  S1699-695X2015000200010-1
# 2320    476  S0211-69952011000500011-3
#
#                                           notas_limpias  duplicados conjunto
# 0     pacient cincuent antecedent personal acudi m d...       False    train
# 1     muj antecedent resident hospital present odino...       False    train
# 2     muj acudi refir dificult andar fatig agud hor ...       False    train
# 3     febrer ingres urgenci bomber tras crisis carac...       False    train
# 4     muj dem s san acudi servici urgenci s ntom fie...       False    train
# ...                                                 ...         ...      ...
# 2316  pacient edad sex femenin oper extrofi cloac re...       False   anotar
# 2317  muj consult urgenci cuadr hor evoluci n dolor ...       False   anotar
# 2318  pacient edad antecedent inter s diagnostic enf...        True   anotar
# 2319  muj acud consult atenci n primari dolor ambas ...       False   anotar
# 2320  empty datafram columns hombr diabet tip larg e...       False   anotar
#
# [2321 rows x 5 columns]

# %% [markdown]
# Vemos todos los duplicados (en el conjunto MOD, test y train) sin aplicar TF-IDF, observando a qué conjunto pertenecen. Vemos que no hay notas cruzadas es decir, todas las notas duplicadas pertenecen al mismo conjunto

# %%
# Señalamos los duplicados de la combinación de archivos
df_final["duplicados"] = df_final.notas_limpias.duplicated(keep = False)
df_final[df_final.duplicados == True].sort_values("notas_limpias")
# Out:
#       index                            fichero  \
# 2068    224       es-S0210-56912007000200007-3
# 2295    451          S0210-56912007000200007-3
# 1681   1051      casos_clinicos_profesiones120
# 1755   1199      casos_clinicos_profesiones193
# 128     257  caso_clinico_atencion_primaria161
# 129     259  caso_clinico_atencion_primaria162
# 2069    225       es-S0376-78922009000300005-1
# 2313    469          S0376-78922009000300005-1
# 1844      0       es-S1137-66272013000200022-1
# 2318    474          S1137-66272013000200022-1
# 2067    223       es-S0210-56912009000900008-1
# 2296    452          S0210-56912009000900008-1
# 2141    297         caso_clinico_radiologia867
# 2240    396          S1137-66272006000100012-1
#
#                                           notas_limpias  duplicados conjunto
# 2068  faringitis hac d as fiebr elev artralgi hor pr...        True   anotar
# 2295  faringitis hac d as fiebr elev artralgi hor pr...        True   anotar
# 1681  hombr emple industri metal rgic oper maquinari...        True     test
# 1755  hombr emple industri metal rgic oper maquinari...        True     test
# 128   motiv consult agres impuls insomni mal control...        True    train
# 129   motiv consult agres impuls insomni mal control...        True    train
# 2069  pacient cas unigest gemel histori infeccion re...        True   anotar
# 2313  pacient cas unigest gemel histori infeccion re...        True   anotar
# 1844  pacient edad antecedent inter s diagnostic enf...        True   anotar
# 2318  pacient edad antecedent inter s diagnostic enf...        True   anotar
# 2067  trat var n antecedent neoplasi pulmon carcinom...        True   anotar
# 2296  trat var n antecedent neoplasi pulmon carcinom...        True   anotar
# 2141  var n present fiebr hemoptisis antecedent pers...        True   anotar
# 2240  var n present fiebr hemoptisis antecedent pers...        True   anotar

# %%
# Vemos el aspecto del conjunto de datos de las notas encontradas
df
# Out:
#                                                  notas  \
# 0      Paciente de 33 años de edad sin antecedentes...
# 1       Varón soltero de 37 años de edad, trabajado...
# 2    Empty DataFrame\nColumns: [Varón de 45 años, t...
# 3                             Anámnesis e historia ...
# 4                                       Motivo de c...
# ..                                                 ...
# 472    Paciente de 18 años de edad y sexo femenino ...
# 473    Mujer de 47 años que consulta en urgencias p...
# 474    Paciente de 33 años de edad sin antecedentes...
# 475    Mujer de 40 años que acude a la consulta de ...
# 476  Empty DataFrame\nColumns: [Hombre de 47 años, ...
#
#                                nombre  \
# 0        es-S1137-66272013000200022-1
# 1        es-S0376-78922009000100011-1
# 2        es-S1137-66272011000100013-1
# 3            caso_clinico_urologia434
# 4    caso_clinico_atencion_primaria20
# ..                                ...
# 472         S0376-78922009000200008-1
# 473         S1887-85712012000400006-1
# 474         S1137-66272013000200022-1
# 475         S1699-695X2015000200010-1
# 476         S0211-69952011000500011-3
#
#                                          notas_limpias  duplicados
# 0    pacient edad antecedent inter s diagnostic enf...        True
# 1    var n solter edad trabaj camp envi servici hos...       False
# 2    empty datafram columns var n trabaj canter dia...       False
# 3    an mnesis histori cl nic acud deriv m dic aten...       False
# 4    motiv consult voluntad vital anticip vva enfoq...       False
# ..                                                 ...         ...
# 472  pacient edad sex femenin oper extrofi cloac re...       False
# 473  muj consult urgenci cuadr hor evoluci n dolor ...       False
# 474  pacient edad antecedent inter s diagnostic enf...        True
# 475  muj acud consult atenci n primari dolor ambas ...       False
# 476  empty datafram columns hombr diabet tip larg e...       False
#
# [477 rows x 4 columns]

# %% [markdown]
# # Duplicidades TF-IDF
#
# Implementación del enfoque TF-IDF para calcular la similitud entre documentos. Cuanto más cerca el valor a 1, más parecidos son.

# %% [markdown]
# ## Duplicidades notas del conjunto MOD

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
tfidf = TfidfVectorizer().fit_transform(df.notas_limpias)
pairwise_similarity = tfidf * tfidf.T
# Calculamos la similitud
conjunto_MOD = pairwise_similarity.toarray()
conjunto_MOD
# Out:
# array([[1.        , 0.01788417, 0.0295041 , ..., 1.        , 0.01977448,
#         0.08711051],
#        [0.01788417, 1.        , 0.05835762, ..., 0.01788417, 0.04574716,
#         0.07048654],
#        [0.0295041 , 0.05835762, 1.        , ..., 0.0295041 , 0.0355382 ,
#         0.10160884],
#        ...,
#        [1.        , 0.01788417, 0.0295041 , ..., 1.        , 0.01977448,
#         0.08711051],
#        [0.01977448, 0.04574716, 0.0355382 , ..., 0.01977448, 1.        ,
#         0.02120958],
#        [0.08711051, 0.07048654, 0.10160884, ..., 0.08711051, 0.02120958,
#         1.        ]])

# %% [markdown]
# Transformamos la matriz de similitud a formato long para analizar qué pares de notas son las que tienen mayor similitud. Esto sólo lo hacemos, en el código de abajo, para las notas usasdas para enriquecer el conjunto de datos. Se compara una la similitud de una nota con todas las demás (477 * 477)

# %%
conjunto_MOD = pd.DataFrame(conjunto_MOD)
# Aplanamos la matriz para trabajar
conjunto_MOD = conjunto_MOD.unstack()
conjunto_MOD = conjunto_MOD.reset_index()
conjunto_MOD
# Out:
#         level_0  level_1         0
# 0             0        0  1.000000
# 1             0        1  0.017884
# 2             0        2  0.029504
# 3             0        3  0.035997
# 4             0        4  0.005037
# ...         ...      ...       ...
# 227524      476      472  0.005852
# 227525      476      473  0.076561
# 227526      476      474  0.087111
# 227527      476      475  0.021210
# 227528      476      476  1.000000
#
# [227529 rows x 3 columns]

# %%
# Creamos el conjunto de datos. Las dos primeras columnas identifican la posición original en la matriz del valor TF-IDF
conjunto_MOD = conjunto_MOD.set_axis(['row', 'column', 'value'], axis=1, inplace=False)
conjunto_MOD = conjunto_MOD.sort_values(by=["value"], ascending = False)
conjunto_MOD = conjunto_MOD[conjunto_MOD.row != conjunto_MOD.column]
# Ponemos punto de corte a 0.35 de forma arbritaria
conjunto_MOD = conjunto_MOD[conjunto_MOD.value > 0.35]
conjunto_MOD
# Out:
#         row  column     value
# 107299  224     451  1.000000
# 215351  451     224  1.000000
# 223938  469     225  1.000000
# 107794  225     469  1.000000
# 189189  396     297  1.000000
# 142065  297     396  1.000000
# 474       0     474  1.000000
# 226098  474       0  1.000000
# 106823  223     452  1.000000
# 215827  452     223  1.000000
# 22034    46      92  0.968831
# 43930    92      46  0.968831
# 81867   171     300  0.780568
# 143271  300     171  0.780568
# 98361   206      99  0.681185
# 47429    99     206  0.681185
# 21552    45      87  0.632758
# 41544    87      45  0.632758
# 8371     17     262  0.621584
# 124991  262      17  0.621584
# 147992  310     122  0.586041
# 58504   122     310  0.586041
# 198386  415     431  0.520530
# 206002  431     415  0.520530
# 92263   193     202  0.517967
# 96547   202     193  0.517967
# 29682    62     108  0.463468
# 51578   108      62  0.463468
# 125284  262     310  0.419611
# 148132  310     262  0.419611
# 93652   196     160  0.400272
# 76516   160     196  0.400272
# 58211   122      17  0.395096
# 8231     17     122  0.395096
# 1062      2     108  0.391296
# 51518   108       2  0.391296
# 1016      2      62  0.379343
# 29576    62       2  0.379343
# 83311   174     313  0.374489
# 149475  313     174  0.374489
# 73294   153     313  0.361150
# 149454  313     153  0.361150
# 8419     17     310  0.360599
# 147887  310      17  0.360599
# 8246     17     137  0.357584
# 65366   137      17  0.357584
# 58456   122     262  0.354555
# 125096  262     122  0.354555
# 149335  313      34  0.353948
# 16531    34     313  0.353948
# 124810  261     313  0.352727
# 149562  313     261  0.352727

# %% [markdown]
# Vemos que hay 26 notas, en el conjunto MOD, con un valor de TF-IDF > 0.35

# %%
len(conjunto_MOD)
# Out:
# 52

# %% [markdown]
# Imprimimos qué notas son

# %%
# Mediante un bucle recorremos todos los archivos con alta similiradidad pareados dos a dos
for i in range(0, len(conjunto_MOD)):
  print("Notas repetidas:", df.iloc[conjunto_MOD.iloc[i,0],1], df.iloc[conjunto_MOD.iloc[i,1],1])
# Out:
# Notas repetidas: es-S0210-56912007000200007-3 S0210-56912007000200007-3
# Notas repetidas: S0210-56912007000200007-3 es-S0210-56912007000200007-3
# Notas repetidas: S0376-78922009000300005-1 es-S0376-78922009000300005-1
# Notas repetidas: es-S0376-78922009000300005-1 S0376-78922009000300005-1
# Notas repetidas: S1137-66272006000100012-1 caso_clinico_radiologia867
# Notas repetidas: caso_clinico_radiologia867 S1137-66272006000100012-1
# Notas repetidas: es-S1137-66272013000200022-1 S1137-66272013000200022-1
# Notas repetidas: S1137-66272013000200022-1 es-S1137-66272013000200022-1
# Notas repetidas: es-S0210-56912009000900008-1 S0210-56912009000900008-1
# Notas repetidas: S0210-56912009000900008-1 es-S0210-56912009000900008-1
# Notas repetidas: cc_covid81 cc_covid114
# Notas repetidas: cc_covid114 cc_covid81
# Notas repetidas: casos_clinicos_cardiologia470 casos_clinicos_cardiologia44
# Notas repetidas: casos_clinicos_cardiologia44 casos_clinicos_cardiologia470
# Notas repetidas: cc_reumatologia238 cc_reumatologia240
# Notas repetidas: cc_reumatologia240 cc_reumatologia238
# Notas repetidas: casos_clinicos_cardiologia187 casos_clinicos_cardiologia363
# Notas repetidas: casos_clinicos_cardiologia363 casos_clinicos_cardiologia187
# Notas repetidas: casos_clinicos_cardiologia475 casos_clinicos_cardiologia47
# Notas repetidas: casos_clinicos_cardiologia47 casos_clinicos_cardiologia475
# Notas repetidas: casos_clinicos_cardiologia46 casos_clinicos_cardiologia474
# Notas repetidas: casos_clinicos_cardiologia474 casos_clinicos_cardiologia46
# Notas repetidas: S1139-13752009000300010-2 S1139-13752009000300010-1
# Notas repetidas: S1139-13752009000300010-1 S1139-13752009000300010-2
# Notas repetidas: casos_clinicos_cardiologia308 casos_clinicos_cardiologia165
# Notas repetidas: casos_clinicos_cardiologia165 casos_clinicos_cardiologia308
# Notas repetidas: es-S1137-66272011000100013-2 es-S1137-66272011000100013-3
# Notas repetidas: es-S1137-66272011000100013-3 es-S1137-66272011000100013-2
# Notas repetidas: casos_clinicos_cardiologia47 casos_clinicos_cardiologia46
# Notas repetidas: casos_clinicos_cardiologia46 casos_clinicos_cardiologia47
# Notas repetidas: casos_clinicos_cardiologia319 casos_clinicos_cardiologia434
# Notas repetidas: casos_clinicos_cardiologia434 casos_clinicos_cardiologia319
# Notas repetidas: casos_clinicos_cardiologia474 casos_clinicos_cardiologia475
# Notas repetidas: casos_clinicos_cardiologia475 casos_clinicos_cardiologia474
# Notas repetidas: es-S1137-66272011000100013-1 es-S1137-66272011000100013-3
# Notas repetidas: es-S1137-66272011000100013-3 es-S1137-66272011000100013-1
# Notas repetidas: es-S1137-66272011000100013-1 es-S1137-66272011000100013-2
# Notas repetidas: es-S1137-66272011000100013-2 es-S1137-66272011000100013-1
# Notas repetidas: caso_clinico_atencion_primaria105 caso_clinico_atencion_primaria50
# Notas repetidas: caso_clinico_atencion_primaria50 caso_clinico_atencion_primaria105
# Notas repetidas: caso_clinico_atencion_primaria130 caso_clinico_atencion_primaria50
# Notas repetidas: caso_clinico_atencion_primaria50 caso_clinico_atencion_primaria130
# Notas repetidas: casos_clinicos_cardiologia475 casos_clinicos_cardiologia46
# Notas repetidas: casos_clinicos_cardiologia46 casos_clinicos_cardiologia475
# Notas repetidas: casos_clinicos_cardiologia475 casos_clinicos_cardiologia477
# Notas repetidas: casos_clinicos_cardiologia477 casos_clinicos_cardiologia475
# Notas repetidas: casos_clinicos_cardiologia474 casos_clinicos_cardiologia47
# Notas repetidas: casos_clinicos_cardiologia47 casos_clinicos_cardiologia474
# Notas repetidas: caso_clinico_atencion_primaria50 caso_clinico_atencion_primaria116
# Notas repetidas: caso_clinico_atencion_primaria116 caso_clinico_atencion_primaria50
# Notas repetidas: caso_clinico_atencion_primaria58 caso_clinico_atencion_primaria50
# Notas repetidas: caso_clinico_atencion_primaria50 caso_clinico_atencion_primaria58

# %% [markdown]
# ---

# %% [markdown]
# ## Duplicidades notas de todos los conjuntos a la vez

# %% [markdown]
# Comprobamos la no pertenencia de notas del conjunto de datos con el que vamos a enriquecer (MOD), en train y test.
#
# Hacemos un análisis TF-IDF con los tres conjuntos de datos (train, test y las notas identificadas) a la vez

# %%
# Ordenamos para que notas pertenecientes a conjuntos en concreto estén consecutivas
df_final = df_final.sort_values(["conjunto", "index"])
df_final
# Out:
#       index                           fichero  \
# 1844      0      es-S1137-66272013000200022-1
# 1845      1      es-S0376-78922009000100011-1
# 1846      2      es-S1137-66272011000100013-1
# 1847      3          caso_clinico_urologia434
# 1848      4  caso_clinico_atencion_primaria20
# ...     ...                               ...
# 1495   2991         cc_otorrinolaringologia54
# 1496   2993         cc_otorrinolaringologia56
# 1497   2995         cc_otorrinolaringologia60
# 1498   2997         cc_otorrinolaringologia72
# 1499   2999         cc_otorrinolaringologia96
#
#                                           notas_limpias  duplicados conjunto
# 1844  pacient edad antecedent inter s diagnostic enf...        True   anotar
# 1845  var n solter edad trabaj camp envi servici hos...       False   anotar
# 1846  empty datafram columns var n trabaj canter dia...       False   anotar
# 1847  an mnesis histori cl nic acud deriv m dic aten...       False   anotar
# 1848  motiv consult voluntad vital anticip vva enfoq...       False   anotar
# ...                                                 ...         ...      ...
# 1495  present cas pacient present hipoacusi hor evol...       False    train
# 1496  pacient muj hipoacusi bilateral progres larg e...       False    train
# 1497  present cas muj acud urgenci odinofagi fiebr e...       False    train
# 1498  present cas var n edad jornaler profesi n pres...       False    train
# 1499  var n adenopat laterocervical derech evoluci n...       False    train
#
# [2321 rows x 5 columns]

# %%
df_final.conjunto.value_counts()
# Out:
# train     1500
# anotar     477
# test       344
# Name: conjunto, dtype: int64

# %% [markdown]
# Las observaciones que van desde la 0 a la 477 se corresponden con el conjunto a anotar

# %%
df_final.iloc[476]
# Out:
# index                                                          476
# fichero                                  S0211-69952011000500011-3
# notas_limpias    empty datafram columns hombr diabet tip larg e...
# duplicados                                                   False
# conjunto                                                    anotar
# Name: 2320, dtype: object

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
tfidf = TfidfVectorizer().fit_transform(df_final.notas_limpias)
pairwise_similarity = tfidf * tfidf.T
procesado_todosConjuntos = pairwise_similarity.toarray()
procesado_todosConjuntos
# Out:
# array([[1.        , 0.01452653, 0.02689272, ..., 0.0190059 , 0.02443002,
#         0.03169734],
#        [0.01452653, 1.        , 0.04839181, ..., 0.04549546, 0.11495877,
#         0.04581697],
#        [0.02689272, 0.04839181, 1.        , ..., 0.05943574, 0.07723135,
#         0.0499771 ],
#        ...,
#        [0.0190059 , 0.04549546, 0.05943574, ..., 1.        , 0.03222219,
#         0.05447175],
#        [0.02443002, 0.11495877, 0.07723135, ..., 0.03222219, 1.        ,
#         0.07594992],
#        [0.03169734, 0.04581697, 0.0499771 , ..., 0.05447175, 0.07594992,
#         1.        ]])

# %%
procesado_todosConjuntos = pd.DataFrame(procesado_todosConjuntos)
# Aplanamos la matriz para trabajar
procesado_todosConjuntos = procesado_todosConjuntos.unstack()
procesado_todosConjuntos = procesado_todosConjuntos.reset_index()
procesado_todosConjuntos
# Out:
#          level_0  level_1         0
# 0              0        0  1.000000
# 1              0        1  0.014527
# 2              0        2  0.026893
# 3              0        3  0.025827
# 4              0        4  0.005028
# ...          ...      ...       ...
# 5387036     2320     2316  0.038202
# 5387037     2320     2317  0.012550
# 5387038     2320     2318  0.054472
# 5387039     2320     2319  0.075950
# 5387040     2320     2320  1.000000
#
# [5387041 rows x 3 columns]

# %% [markdown]
# Relaciones con un valor de TF-IDF mayor a 0.35

# %%
# Creamos el conjunto de datos. Las dos primeras columnas identifican la posición original en la matriz del valor TF-IDF
procesado_todosConjuntos = procesado_todosConjuntos.set_axis(['row', 'column', 'value'], axis=1, inplace=False)
procesado_todosConjuntos = procesado_todosConjuntos.sort_values(by=["value", 'row', 'column'], ascending = False)
# Eliminamos aquellas observaciones de notas que son similares consigo mismas
procesado_todosConjuntos = procesado_todosConjuntos[procesado_todosConjuntos.row != procesado_todosConjuntos.column]

# Ponemos punto de corte a 0.35 de forma arbritaria
procesado_todosConjuntos = procesado_todosConjuntos[procesado_todosConjuntos.value > 0.35]
procesado_todosConjuntos
# Out:
#           row  column     value
# 1100154   474       0  1.000000
# 1088774   469     225  1.000000
# 919413    396     297  1.000000
# 689733    297     396  1.000000
# 522694    225     469  1.000000
# ...       ...     ...       ...
# 1385047   596    1731  0.350206
# 4227144  1821     603  0.350122
# 1401384   603    1821  0.350122
# 4620750  1990    1960  0.350079
# 4551150  1960    1990  0.350079
#
# [1578 rows x 3 columns]

# %%
# Número de relaciones con más de un 0.4 de valor TF-IDF
len(procesado_todosConjuntos)
# Out:
# 1578

# %% [markdown]
# Vemos las notas con dicho valor de relación

# %%
# Mediante un bucle recorremos todos los archivos con alta similiradidad pareados dos a dos
#for i in range(0, len(procesado_todosConjuntos)):
#  print("Notas repetidas:", df_final.iloc[procesado_todosConjuntos.iloc[i,0],1], df_final.iloc[procesado_todosConjuntos.iloc[i,1],1])

# %% [markdown]
# ---

# %% [markdown]
# Vamos a comparar las notas a anotar (MOD) con las notas del conjunto de train, por un lado y con las notas del conjunto de test por otro lado)
#
# Lo hacemos así porque no tiene sentido comparar la similitud entre las notas del conjunto MEDDOPROF train con las notas del conjunto MEDDOPROF test, o las notas del conjunto MOD consigo mismas.
#
# Dado que `procesado_todosConjuntos` viene de `datos_final` que fue ordenado por la columna conjunto, las 477 primeras observaciones vienen del conjunto MOD (por tanto la columa row o column debe tener valores de este conjunto y la columna complementaria column o row debe tener valores fuera de este conjunto). Así evitamos volver a comparar las notas que provienen del conjunto MOD dos a dos.

# %%
#De los potenciales conflictos nos quedamos con aquellos cuya fila es menor de 477 (corresponden con las notas de train) y una columna mayor o igual a 477, es decir que caiga en train o en test)
similaritud_anotar = procesado_todosConjuntos[(procesado_todosConjuntos.row < 477) & (procesado_todosConjuntos.column >= 477)]
similaritud_anotar
# Out:
#          row  column     value
# 891934   384     670  0.981696
# 159885    68    2057  0.944289
# 246843   106     817  0.919287
# 166805    71    2014  0.853177
# 5516       2     874  0.785477
# 144777    62     875  0.785043
# 251544   108     876  0.731334
# 881242   379    1583  0.673338
# 328118   141     857  0.673209
# 58843     25     818  0.661398
# 165649    71     858  0.654515
# 168482    72    1370  0.591343
# 882549   380     569  0.583220
# 277847   119    1648  0.578753
# 511472   220     852  0.573057
# 112285    48     877  0.521973
# 1078498  464    1554  0.500225
# 253856   109     867  0.489612
# 757348   326     702  0.477241
# 485944   209     855  0.432136
# 2804       1     483  0.423401
# 310071   133    1378  0.420516
# 1008083  434     769  0.416775
# 354790   152    1998  0.407346
# 310051   133    1358  0.398007
# 168470    72    1358  0.381982
# 760529   327    1562  0.373029
# 676532   291    1121  0.359515

# %%
len(similaritud_anotar)
# Out:
# 28

# %%
# Mediante un bucle recorremos todos los archivos con alta similaridad pareados dos a dos
for i in range(0, len(similaritud_anotar)):
  print("Notas repetidas:", df_final.iloc[similaritud_anotar.iloc[i,0],1], df_final.iloc[similaritud_anotar.iloc[i,1],1])
# Out:
# Notas repetidas: S0365-66912011001000003-4 casos_clinicos_profesiones132
# Notas repetidas: cc_reumatologia353 casos_clinicos_profesiones79
# Notas repetidas: cc_reumatologia60 cc_reuma56
# Notas repetidas: es-S0465-546X2014000400012-1 casos_clinicos_profesiones3
# Notas repetidas: es-S1137-66272011000100013-1 S1137-66272011000100013-1
# Notas repetidas: es-S1137-66272011000100013-2 S1137-66272011000100013-2
# Notas repetidas: es-S1137-66272011000100013-3 S1137-66272011000100013-3
# Notas repetidas: S0211-57352014000400011-1 caso_clinico_psiquiatria306
# Notas repetidas: es-S0465-546X2014000300010-1 S0465-546X2014000300010-1
# Notas repetidas: cc_reumatologia62 cc_reuma58
# Notas repetidas: es-S0465-546X2014000400012-1 S0465-546X2014000400012-1
# Notas repetidas: caso_clinico_oftalmologia285 caso_clinico_oftalmologia40
# Notas repetidas: S0211-57352014000400010-1 caso_clinico_psiquiatria305
# Notas repetidas: cc_geneticas200 caso_clinico_psiquiatria372
# Notas repetidas: es-S0465-546X2009000300008-1 S0465-546X2009000300008-1
# Notas repetidas: es-S1137-66272014000100021-1 S1137-66272014000100021-1
# Notas repetidas: S0211-57352015000100011-2 caso_clinico_psiquiatria278
# Notas repetidas: es-S1132-62552015000100006-1 S1132-62552015000100006-1
# Notas repetidas: S1578-25492016000400004-1 casos_clinicos_profesiones163
# Notas repetidas: es-S0465-546X2011000300007-1 S0465-546X2011000300007-1
# Notas repetidas: es-S0376-78922009000100011-1 S0376-78922009000100011-1
# Notas repetidas: caso_clinico_oftalmologia279 caso_clinico_oftalmologia89
# Notas repetidas: S0211-57352002000100009-1 casos_clinicos_profesiones228
# Notas repetidas: casos_clinicos_cardiologia377 casos_clinicos_profesiones1
# Notas repetidas: caso_clinico_oftalmologia279 caso_clinico_oftalmologia101
# Notas repetidas: caso_clinico_oftalmologia285 caso_clinico_oftalmologia101
# Notas repetidas: S0211-57352014000300007-1 caso_clinico_psiquiatria285
# Notas repetidas: casos_clinicos_pediatria12 caso_clinico_medicina_interna1388

# %% [markdown]
# Después de aplicar este script se deben anotar las notas con BRAT
